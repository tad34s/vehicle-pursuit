# %%
import json
import matplotlib.pyplot as plt

# %%
path = './models/13-08-23 142516/training-data.json'

with open(path, 'r') as f:
  data = json.load(f)
data
# Out:
# {'num_epochs': 300,
#  'results': [6.543519750237465,
#   329.19083389942534,
#   10.877719850745052,
#   20.752945975633338,
#   488.5952437981032,
#   488.5972150056623,
#   21.60253583267331,
#   8.72891634190455,
#   9.526854339055717,
#   504.02700760262087,
#   392.49911620328203,
#   376.17604471743107,
#   32.42738503939472,
#   107.28739496832713,
#   202.43433587346226,
#   414.9590630396269,
#   159.98253656295128,
#   442.04264369932935,
#   365.58867199812084,
#   328.976901515387,
#   158.86893379455432,
#   422.2939327452332,
#   368.44911000458524,
#   442.46431839605793,
#   424.6231549754739,
#   142.33871729066595,
#   876.3866251811851,
#   1232.6915334309451,
#   201.76216396177188,
#   2097.142497376539,
#   420.31734634004533,
#   442.62035587150604,
#   464.1725965575315,
#   418.31010239897296,
#   266.3829820691608,
#   464.4953773682937,
#   420.9787450134754,
#   511.4154374282807,
#   487.0123608482536,
#   350.93219571979716,
#   489.6981916949153,
# ...

# %%
plt.plot(range(data['num_epochs']), data['results'])
